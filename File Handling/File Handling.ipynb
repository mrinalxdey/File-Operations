# %% [markdown]
# # File Handling

# %%
import csv

# %%
with open('..\\olist_customers_dataset.csv', 'r') as f:
    print(f.read())

# %%
with open('part-00000.txt', 'r') as f:
    print(f.read())
# Out:
# This is a text file

# %%
with open('notes.txt', 'w') as f:
    f.write("- Remember to buy milk.")

with open('notes.txt', 'r') as f:
    print(f.read())
# Out:
# - Remember to buy milk.

# %%
with open('notes.txt', 'w') as f:
    f.write("- Remember to buy oil.")

# %%
with open('notes.txt', 'r') as f:
    print(f.read())
# Out:
# - Remember to buy oil.

# %%
with open('data.csv', 'w', newline='') as f:
    writer = csv.writer(f, delimiter='|')
    writer.writerow(['Name', 'Age'])
    writer.writerow(['Alice', 24])
    writer.writerow(['Bob', 32])
    writer.writerow(['Yashi', 24])
    writer.writerow(['Isha', 23])

# %%
with open('data.csv', 'r') as f:
    print(f.read())
# Out:
# Name|Age
# Alice|24
# Bob|32
# Yashi|24
# Isha|23
